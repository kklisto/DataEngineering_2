# %%
import feedparser
import pandas as pd

# Récupération du flux RSS
rss_url = 'https://www.lemonde.fr/rss/une.xml'
feed = feedparser.parse(rss_url)

# Conversion du flux RSS en DataFrame
rss_df = pd.DataFrame(feed.entries)

# %%
rss_df = rss_df.iloc[:10,]
rss_df
# Out:
#                                                title  \
# 0  Manifestations du 6 avril contre la réforme de...
# 1  Guerre en Ukraine en direct : la Russie exclut...
# 2  Choix énergétiques de la France : le rapport a...
# 3  Thomas Bangalter, ex-Daft Punk : « J’aime l’id...
# 4  Maintien de l’ordre dans les autres pays d’Eur...
# 5         Le vol de vélos, un obstacle à la pratique
# 6  Grand Paris Express : une filiale de Vinci dev...
# 7  Usines, agriculture, eau potable… Quelles quan...
# 8  La Chine, grande exception dans le déclin mond...
# 9  Laurent Nuñez, un préfet de police au garde-à-...
#
#                                         title_detail  \
# 0  {'type': 'text/plain', 'language': None, 'base...
# 1  {'type': 'text/plain', 'language': None, 'base...
# 2  {'type': 'text/plain', 'language': None, 'base...
# 3  {'type': 'text/plain', 'language': None, 'base...
# 4  {'type': 'text/plain', 'language': None, 'base...
# 5  {'type': 'text/plain', 'language': None, 'base...
# ...

# %%
rss_df.shape
# Out:
# (10, 13)

# %%
# Export de la DataFrame en CSV
rss_df.to_csv('lemonde_rss.csv', index=False)
