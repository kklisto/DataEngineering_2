# %%
import feedparser
import pandas as pd

# Récupération du flux RSS
rss_url = 'https://www.lemonde.fr/rss/une.xml'
feed = feedparser.parse(rss_url)

# Conversion du flux RSS en DataFrame
rss_df = pd.DataFrame(feed.entries)

# %%
rss_df = rss_df.iloc[:10,]
rss_df
# Out:
#                                                title  \
# 0  Retraites : Elisabeth Borne assure « partager ...
# 1  Assassinat de Samuel Paty : le parquet nationa...
# 2  Au procès des attentats de Bruxelles, la parol...
# 3  En Argentine, une sécheresse historique étouff...
# 4  Guerre en Ukraine, en direct : Moscou n’envisa...
# 5  Picasso : des expositions, des documentaires, ...
# 6  Emmanuel Macron en Chine : « Le dialogue a bel...
# 7  Israël face à plusieurs fronts, au sud du Liba...
# 8  Entre l’Etat et les sociétés d’autoroutes, un ...
# 9  Au Sahel, près d’un million d’enfants exposés ...
#
#                                         title_detail  \
# 0  {'type': 'text/plain', 'language': None, 'base...
# 1  {'type': 'text/plain', 'language': None, 'base...
# 2  {'type': 'text/plain', 'language': None, 'base...
# 3  {'type': 'text/plain', 'language': None, 'base...
# 4  {'type': 'text/plain', 'language': None, 'base...
# 5  {'type': 'text/plain', 'language': None, 'base...
# 6  {'type': 'text/plain', 'language': None, 'base...
# 7  {'type': 'text/plain', 'language': None, 'base...
# 8  {'type': 'text/plain', 'language': None, 'base...
# 9  {'type': 'text/plain', 'language': None, 'base...
#
#                          published                   published_parsed  \
# 0  Fri, 07 Apr 2023 12:58:00 +0200  (2023, 4, 7, 10, 58, 0, 4, 97, 0)
# 1  Fri, 07 Apr 2023 12:36:06 +0200  (2023, 4, 7, 10, 36, 6, 4, 97, 0)
# 2  Fri, 07 Apr 2023 10:47:11 +0200  (2023, 4, 7, 8, 47, 11, 4, 97, 0)
# 3  Fri, 07 Apr 2023 11:00:12 +0200   (2023, 4, 7, 9, 0, 12, 4, 97, 0)
# 4  Fri, 07 Apr 2023 11:20:10 +0200  (2023, 4, 7, 9, 20, 10, 4, 97, 0)
# 5  Fri, 07 Apr 2023 04:00:00 +0200    (2023, 4, 7, 2, 0, 0, 4, 97, 0)
# 6  Fri, 07 Apr 2023 09:30:00 +0200   (2023, 4, 7, 7, 30, 0, 4, 97, 0)
# 7  Fri, 07 Apr 2023 10:01:39 +0200   (2023, 4, 7, 8, 1, 39, 4, 97, 0)
# 8  Fri, 07 Apr 2023 10:19:02 +0200   (2023, 4, 7, 8, 19, 2, 4, 97, 0)
# 9  Fri, 07 Apr 2023 09:21:47 +0200  (2023, 4, 7, 7, 21, 47, 4, 97, 0)
#
#                                              summary  \
# 0  La cheffe du gouvernement avait marqué sa diff...
# 1  Le PNAT demande que l’infraction la plus grave...
# 2  Dans la capitale belge, l’interrogatoire des a...
# 3  Le manque de précipitations et des température...
# 4  Depuis la Turquie, Sergueï Lavrov a affirmé qu...
# 5  Le cinquantième anniversaire de la disparition...
# 6  Accueilli trois jours par Xi Jinping, le prési...
# 7  Des tirs de roquettes palestiniens, d’une ampl...
# 8  Quand les pouvoirs publics manquent d’argent p...
# 9  L’Unicef appelle les gouvernements du Niger, d...
#
#                                       summary_detail  \
# 0  {'type': 'text/html', 'language': None, 'base'...
# 1  {'type': 'text/html', 'language': None, 'base'...
# 2  {'type': 'text/html', 'language': None, 'base'...
# 3  {'type': 'text/html', 'language': None, 'base'...
# 4  {'type': 'text/html', 'language': None, 'base'...
# 5  {'type': 'text/html', 'language': None, 'base'...
# 6  {'type': 'text/html', 'language': None, 'base'...
# 7  {'type': 'text/html', 'language': None, 'base'...
# 8  {'type': 'text/html', 'language': None, 'base'...
# 9  {'type': 'text/html', 'language': None, 'base'...
#
#                                                   id  guidislink  \
# 0  https://www.lemonde.fr/politique/article/2023/...        True
# 1  https://www.lemonde.fr/societe/article/2023/04...        True
# 2  https://www.lemonde.fr/international/article/2...        True
# 3  https://www.lemonde.fr/economie/article/2023/0...        True
# 4  https://www.lemonde.fr/international/live/2023...        True
# 5  https://www.lemonde.fr/culture/article/2023/04...        True
# 6  https://www.lemonde.fr/international/live/2023...        True
# 7  https://www.lemonde.fr/international/article/2...        True
# 8  https://www.lemonde.fr/economie/article/2023/0...        True
# 9  https://www.lemonde.fr/afrique/article/2023/04...        True
#
#                                                 link  \
# 0  https://www.lemonde.fr/politique/article/2023/...
# 1  https://www.lemonde.fr/societe/article/2023/04...
# 2  https://www.lemonde.fr/international/article/2...
# 3  https://www.lemonde.fr/economie/article/2023/0...
# 4  https://www.lemonde.fr/international/live/2023...
# 5  https://www.lemonde.fr/culture/article/2023/04...
# 6  https://www.lemonde.fr/international/live/2023...
# 7  https://www.lemonde.fr/international/article/2...
# 8  https://www.lemonde.fr/economie/article/2023/0...
# 9  https://www.lemonde.fr/afrique/article/2023/04...
#
#                                                links  \
# 0  [{'rel': 'alternate', 'type': 'text/html', 'hr...
# 1  [{'rel': 'alternate', 'type': 'text/html', 'hr...
# 2  [{'rel': 'alternate', 'type': 'text/html', 'hr...
# 3  [{'rel': 'alternate', 'type': 'text/html', 'hr...
# 4  [{'rel': 'alternate', 'type': 'text/html', 'hr...
# 5  [{'rel': 'alternate', 'type': 'text/html', 'hr...
# 6  [{'rel': 'alternate', 'type': 'text/html', 'hr...
# 7  [{'rel': 'alternate', 'type': 'text/html', 'hr...
# 8  [{'rel': 'alternate', 'type': 'text/html', 'hr...
# 9  [{'rel': 'alternate', 'type': 'text/html', 'hr...
#
#                                        media_content  \
# 0  [{'width': '644', 'height': '322', 'url': 'htt...
# 1  [{'width': '644', 'height': '322', 'url': 'htt...
# 2  [{'width': '644', 'height': '322', 'url': 'htt...
# 3  [{'width': '644', 'height': '322', 'url': 'htt...
# 4  [{'width': '644', 'height': '322', 'url': 'htt...
# 5  [{'width': '644', 'height': '322', 'url': 'htt...
# 6  [{'width': '644', 'height': '322', 'url': 'htt...
# 7  [{'width': '644', 'height': '322', 'url': 'htt...
# 8  [{'width': '644', 'height': '322', 'url': 'htt...
# 9  [{'width': '644', 'height': '322', 'url': 'htt...
#
#                                         media_credit  \
# 0  [{'scheme': 'urn:ebu', 'content': 'CHARLY TRIB...
# 1  [{'scheme': 'urn:ebu', 'content': 'ALAIN JOCAR...
# 2  [{'scheme': 'urn:ebu', 'content': 'JONATHAN DE...
# 3  [{'scheme': 'urn:ebu', 'content': 'ANITA POUCH...
# 4           [{'scheme': 'urn:ebu', 'content': 'AP'}]
# 5   [{'scheme': 'urn:ebu', 'content': 'VOYEZ-VOUS'}]
# 6  [{'scheme': 'urn:ebu', 'content': 'JEAN CLAUDE...
# 7  [{'scheme': 'urn:ebu', 'content': 'MOHAMMED AB...
# 8  [{'scheme': 'urn:ebu', 'content': 'THIBAUD MOR...
# 9  [{'scheme': 'urn:ebu', 'content': 'ISSOUF SANO...
#
#                                     credit
# 0                  CHARLY TRIBALLEAU / AFP
# 1                       ALAIN JOCARD / AFP
# 2                   JONATHAN DE CESARE/AFP
# 3   ANITA POUCHARD SERRA POUR « LE MONDE »
# 4                                       AP
# 5                               VOYEZ-VOUS
# 6  JEAN CLAUDE COUTAUSSE POUR « LE MONDE »
# 7                      MOHAMMED ABED / AFP
# 8                     THIBAUD MORITZ / AFP
# 9                      ISSOUF SANOGO / AFP

# %%
rss_df.shape
# Out:
# (10, 13)

# %%
# Export de la DataFrame en CSV
rss_df.to_csv('lemonde_rss.csv', index=False)
